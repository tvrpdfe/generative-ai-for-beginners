# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 41, 20089, 374, 279, 18172, 11841, 505, 279, 8219, 323, 279, 7928, 304, 279, 25450, 744, 13, 1102, 374, 264, 6962, 14880, 449, 264, 3148, 832, 7716, 52949, 339, 430, 315, 279, 8219, 11, 719, 1403, 9976, 7561, 34902, 3115, 430, 315, 682, 279, 1023, 33975, 304, 279, 25450, 744, 11093, 13, 50789, 374, 832, 315, 279, 72021, 6302, 9621, 311, 279, 19557, 8071, 304, 279, 3814, 13180, 11, 323, 706, 1027, 3967, 311, 14154, 86569, 2533, 1603, 12715, 3925, 13, 1102, 374, 7086, 1306, 279, 13041, 10087, 50789, 8032, 777, 60, 3277, 19894, 505, 9420, 11, 50789, 649, 387, 10107, 3403, 369, 1202, 27000, 3177, 311, 6445, 9621, 35612, 17706, 508, 60, 323, 374, 389, 5578, 279, 4948, 1481, 1315, 478, 5933, 1665, 304, 279, 3814, 13180, 1306, 279, 17781, 323, 50076, 627]
# [b'\n',
#  b'J',
#  b'upiter',
#  b' is',
#  b' the',
#  b' fifth',
#  b' planet',
#  b' from',
#  b' the',
#  b' Sun',
#  b' and',
#  b' the',
#  b' largest',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b'.',
#  b' It',
#  b' is',
#  b' a',
#  b' gas',
#  b' giant',
#  b' with',
#  b' a',
#  b' mass',
#  b' one',
#  b'-th',
#  b'ousand',
#  b'th',
#  b' that',
#  b' of',
#  b' the',
#  b' Sun',
#  b',',
#  b' but',
#  b' two',
#  b'-and',
#  b'-a',
#  b'-half',
#  b' times',
#  b' that',
#  b' of',
#  b' all',
#  b' the',
#  b' other',
#  b' planets',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b' combined',
#  b'.',
#  b' Jupiter',
#  b' is',
#  b' one',
#  b' of',
#  b' the',
#  b' brightest',
#  b' objects',
#  b' visible',
#  b' to',
#  b' the',
#  b' naked',
#  b' eye',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b',',
#  b' and',
#  b' has',
#  b' been',
#  b' known',
#  b' to',
#  b' ancient',
#  b' civilizations',
#  b' since',
#  b' before',
#  b' recorded',
#  b' history',
#  b'.',
#  b' It',
#  b' is',
#  b' named',
#  b' after',
#  b' the',
#  b' Roman',
#  b' god',
#  b' Jupiter',
#  b'.[',
#  b'19',
#  b']',
#  b' When',
#  b' viewed',
#  b' from',
#  b' Earth',
#  b',',
#  b' Jupiter',
#  b' can',
#  b' be',
#  b' bright',
#  b' enough',
#  b' for',
#  b' its',
#  b' reflected',
#  b' light',
#  b' to',
#  b' cast',
#  b' visible',
#  b' shadows',
#  b',[',
#  b'20',
#  b']',
#  b' and',
#  b' is',
#  b' on',
#  b' average',
#  b' the',
#  b' third',
#  b'-b',
#  b'right',
#  b'est',
#  b' natural',
#  b' object',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b' after',
#  b' the',
#  b' Moon',
#  b' and',
#  b' Venus',
#  b'.\n']

# %% [markdown]
# ### Exercise 2: Validate OpenAI API Key Setup
#
# Run the code below to verify that your OpenAI endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
# The OpenAI SDK was updated on Nov 8, 2023 with new guidance for migration
# See: https://github.com/openai/openai-python/discussions/742

## Updated
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
    base_url="https://api.deepseek.com")

deployment="deepseek-v4-flash"

## Updated
def get_completion(prompt):   
    response = client.chat.completions.create(
        model=deployment,
        messages=[
            {"role": "system", "content": "You are a helpful assistant"},
            {"role": "user", "content": prompt},
        ],
        stream=False,
        reasoning_effort="high",
        extra_body={"thinking": {"type": "enabled"}}
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
你是什么模型
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# 我是 DeepSeek 最新版模型，由深度求索公司创造。我是一个纯文本对话助手，擅长回答问题、提供信息和进行各种语言任务。有什么我可以帮你的吗？😊

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# **Lesson Plan: The Martian War of 2076 – A Turning Point in Interplanetary Relations**
#
# **Grade Level:** 9–12 (adaptable for middle school with simplified sources)
# **Subject:** History / Social Studies / Future Studies
# **Duration:** 60 minutes
#
# ---
#
# ### **Lesson Overview**
# Students will examine the causes, key events, and consequences of the Martian War of 2076, the first armed conflict fought between Earth and an off-world colony. Through primary source analysis, collaborative mapping, and debate, they will evaluate the war’s legacy and its relevance to contemporary issues of governance, resource rights, and interplanetary diplomacy.
#
# ---
#
# ### **Learning Objectives**
# By the end of this lesson, students will be able to:
# - Identify three major causes of the Martian War.
# - Describe the turning point at the Battle of Phobos Station.
# - Analyze a primary source document from the war (a speech or personal account).
# - Evaluate the impact of the Olympus Mons Treaty on Earth-Mars relations.
# - Compare the conflict to historical colonial wars on Earth.
#
# ---
#
# ### **Materials Needed**
# - Whiteboard or digital display
# - Printed or digital handouts:
#   - Timeline of the Martian War (attached)
#   - Excerpt from President Okonkwo’s “Red Soil, Blue Skies” speech (2075)
#   - Diary entry of a teenage colonist during the Olympus Mons siege
# - Blank map of Mars with Phobos, Deimos, and major settlements marked
# - Sticky notes (three colors)
# - Exit ticket slips
#
# ---
#
# ### **Key Vocabulary**
# - Terraforming
# - Helium-3 mining
# - Interplanetary Governance Accord (IPGA)
# - Blockade
# - Autonomy
# - War crime (specifically, atmospheric tampering)
#
# ---
#
# ### **Lesson Procedure**
#
# #### **1. Hook: A News Headline from 2076 (5 minutes)**
# Project a fictional breaking‑news alert:
# *“MARS COLONY DECLARES INDEPENDENCE – Earth Forces Mobilize”*
# Ask:
# - *What do you think just happened?*
# - *Why might a colony on another planet want independence?*
# - *How do you predict Earth would respond?*
# Briefly explain that today we’re studying the war that followed, a conflict that redefined humanity’s future in space.
#
# #### **2. Direct Instruction: The Road to War (10 minutes)**
# Use a simple slide deck or verbal narrative to outline the background:
# - **Pre-war context:** By 2070, Mars was home to 2 million settlers, mostly reliant on Earth for advanced technology and governance under the IPGA. Tensions rose over Earth’s control of Helium-3 exports and strict immigration quotas.
# - **Immediate causes:** The Martian Assembly declared universal suffrage in 2074, defying Earth’s appointed governor. In early 2076, Earth imposed a trade blockade; Mars responded by seizing Phobos Station, a key refueling hub.
# - **Major events:**
#   - *Outbreak (March 2076):* Earth’s First Fleet bombards Valles Marineris settlement.
#   - *Turning point (August 2076):* Mars’ makeshift fleet disables Earth’s dreadnought *Unity* at the Battle of Phobos—first use of kinetic missiles in space warfare.
#   - *Olympus Mons siege (October 2076):* Earth’s ground forces pinned down; Martian defenders use knowledge of terrain (lava tubes) to hold out.
# - **Outcome:** Exhausted, both sides sign the Olympus Mons Treaty (December 2076), granting Mars limited autonomy and co‑sovereignty over Phobos. Earth retains jurisdiction over Deimos and deep-space trade routes.
#
# #### **3. Primary Source Analysis – Jigsaw Activity (20 minutes)**
# Divide students into two groups, each receiving a different source:
# - **Group A:** Excerpt from President Okonkwo’s speech justifying the blockade (“…We cannot allow the children of Earth to be held hostage by rebellious colonists…”).
# - **Group B:** Diary of Lena Voss, a 17-year-old colonist holed up during the Olympus Mons siege (“…We’re not rebels—we just want to breathe our own air and elect our own leaders…”).
#
# **Instructions:**
# - Read your source silently (3 min).
# - In your group, discuss: *What is the author’s perspective? What emotions do they convey? What do they want?* (5 min)
# - Jigsaw into pairs with a partner from the other group. Each student summarizes their source, then together they answer: *How do these two accounts differ? Can both be right?* (7 min)
# - Whole-class share-out: one pair highlights the central tension (self-determination vs. unity/security). (5 min)
#
# #### **4. Mapping the War’s Impact – Interactive Activity (10 minutes)**
# Give each pair a blank Mars map. Using three colors of sticky notes, they mark:
# - **Yellow:** Locations of major battles (Phobos, Olympus Mons).
# - **Blue:** Resources or strategic points (Helium-3 refineries near Valles Marineris, Phobos Station).
# - **Red:** Consequences (e.g., “Olympus Mons Treaty → Martian Council formed,” “500,000 displaced,” “Earth loses mining monopoly”).
# Briefly discuss: *Why was Phobos such a crucial target? How did geography (low gravity, lava tubes) shape the war?*
#
# #### **5. Connect & Reflect: Historical Parallels (10 minutes)**
# Facilitate a whole-class discussion:
# - *Does the Martian War remind you of any conflicts on Earth?* (e.g., American Revolution, decolonization wars).
# - *What new challenges did a space environment add?* (distance, life support dependency, no civilians to appeal to).
# - *Was the Olympus Mons Treaty a fair compromise? Why or why not?*
# Encourage students to use vocabulary and evidence from the sources.
#
# #### **6. Exit Ticket (5 minutes)**
# On a slip, students write:
# 1. One cause of the war.
# 2. One legacy of the war that still affects Earth–Mars relations in the 22nd century (e.g., ongoing tension over Deimos, the Martian Council’s growing power).
# Collect as formative assessment.
#
# ---
#
# ### **Assessment**
# - **Formative:** Participation in jigsaw and map activity; exit ticket responses.
# - **Summative (optional extension):** Write a short op-ed from 2077 either supporting or critiquing the treaty, using at least two pieces of evidence from the lesson.
#
# ---
#
# ### **Differentiation**
# - **Support:** Provide a partially completed timeline; use sentence starters for the exit ticket.
# - **Challenge:** Research real-life space law (Outer Space Treaty of 1967) and compare it to the IPGA. Design an alternative peace settlement that could have avoided war.
#
# ---
#
# ### **Attachments**
# 1. **Timeline Handout:** Key dates from 2070–2077.
# 2. **Primary Source Excerpts:** Okonkwo speech and Voss diary.
# 3. **Blank Mars Map:** With major settlements, moons, and the Valles Marineris/Tharsis region.
#
# ---
#
# **Standards Alignment (CCSS for History/Social Studies)**
# - RH.9-10.1: Cite specific textual evidence to support analysis of primary sources.
# - RH.9-10.3: Analyze how individuals, events, and ideas develop and interact.
# - WHST.9-10.1: Write arguments focused on discipline-specific content.

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Jupiter is the biggest planet in our solar system. It is the fifth planet from the Sun. Jupiter is made of gas, not rock like Earth. It shines very brightly in the night sky. People have seen it since long ago and named it after a Roman god.

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.chat.completions.create(
    model=deployment,
    messages=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# The 2020 World Series was played at Globe Life Field in Arlington, Texas. You know, because a global pandemic meant the whole thing was held in a neutral-site bubble. Fun times.

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
